# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/raw/molit/building_ledger/building_ledger_recap_all.parquet")
print(df.size, len(df))
print(df.columns)
df.head()
# Out:
# 1675 25
# Index(['rnum', 'platPlc', 'sigunguCd', 'bjdongCd', 'platGbCd', 'bun', 'ji',
#        'mgmBldrgstPk', 'regstrGbCd', 'regstrGbCdNm', 'regstrKindCd',
#        'regstrKindCdNm', 'newOldRegstrGbCd', 'newOldRegstrGbCdNm',
#        'newPlatPlc', 'bldNm', 'splotNm', 'block', 'lot', 'bylotCnt',
#        'naRoadCd', 'naBjdongCd', 'naUgrndCd', 'naMainBun', 'naSubBun',
#        'platArea', 'archArea', 'bcRat', 'totArea', 'vlRatEstmTotArea', 'vlRat',
#        'mainPurpsCd', 'mainPurpsCdNm', 'etcPurps', 'hhldCnt', 'fmlyCnt',
#        'mainBldCnt', 'atchBldCnt', 'atchBldArea', 'totPkngCnt',
#        'indrMechUtcnt', 'indrMechArea', 'oudrMechUtcnt', 'oudrMechArea',
#        'indrAutoUtcnt', 'indrAutoArea', 'oudrAutoUtcnt', 'oudrAutoArea',
#        'pmsDay', 'stcnsDay', 'useAprDay', 'pmsnoYear', 'pmsnoKikCd',
#        'pmsnoKikCdNm', 'pmsnoGbCd', 'pmsnoGbCdNm', 'hoCnt', 'engrGrade',
#        'engrRat', 'engrEpi', 'gnBldGrade', 'gnBldCert', 'itgBldGrade',
# ...

# %%
df.totPkngCnt
# Out:
# 0      208
# 1     1480
# 2     1108
# 3      525
# 4      349
# 5      375
# 6      212
# 7     1506
# 8      760
# 9      301
# 10      11
# 11     245
# 12      61
# 13       0
# 14     521
# 15       6
# 16      88
# 17       0
# 18     256
# 19     170
# 20       0
# 21    1365
# 22       8
# 23    2902
# 24     968
# Name: totPkngCnt, dtype: object

# %%
df = pd.read_parquet("../data/raw/molit/building_ledger/building_ledger_all.parquet")
print(df.size, len(df))
print(df.columns)
df.head()
# Out:
# 1164065 14735
# Index(['rnum', 'platPlc', 'sigunguCd', 'bjdongCd', 'platGbCd', 'bun', 'ji',
#        'mgmBldrgstPk', 'regstrGbCd', 'regstrGbCdNm', 'regstrKindCd',
#        'regstrKindCdNm', 'newPlatPlc', 'bldNm', 'splotNm', 'block', 'lot',
#        'bylotCnt', 'naRoadCd', 'naBjdongCd', 'naUgrndCd', 'naMainBun',
#        'naSubBun', 'dongNm', 'mainAtchGbCd', 'mainAtchGbCdNm', 'platArea',
#        'archArea', 'bcRat', 'totArea', 'vlRatEstmTotArea', 'vlRat', 'strctCd',
#        'strctCdNm', 'etcStrct', 'mainPurpsCd', 'mainPurpsCdNm', 'etcPurps',
#        'roofCd', 'roofCdNm', 'etcRoof', 'hhldCnt', 'fmlyCnt', 'heit',
#        'grndFlrCnt', 'ugrndFlrCnt', 'rideUseElvtCnt', 'emgenUseElvtCnt',
#        'atchBldCnt', 'atchBldArea', 'totDongTotArea', 'indrMechUtcnt',
#        'indrMechArea', 'oudrMechUtcnt', 'oudrMechArea', 'indrAutoUtcnt',
#        'indrAutoArea', 'oudrAutoUtcnt', 'oudrAutoArea', 'pmsDay', 'stcnsDay',
# ...

# %%
df.bylotCnt
# Out:
# 0         0
# 1         2
# 2         0
# 3         0
# 4         0
#          ..
# 14730     0
# 14731    10
# 14732     0
# 14733     0
# 14734     0
# Name: bylotCnt, Length: 14735, dtype: object

# %%
df = pd.read_parquet("../data/processed/monthly_rent_summary.parquet")
print(df.size, len(df))
df.head()
# Out:
# 6651832 604712
#        ym       date _lawd_cd _region_name rentType  거래건수         평균보증금  \
# 0  201101 2011-01-01    11110          종로구       전세     1  33000.000000
# 1  201101 2011-01-01    11170          용산구       전세     1  20000.000000
# 2  201101 2011-01-01    11200          성동구       전세     1  43000.000000
# 3  201101 2011-01-01    11215          광진구       전세     3  16533.333333
# 4  201101 2011-01-01    11230         동대문구       월세     1   5000.000000
#
#     중앙값보증금  평균월세  중앙값월세     평균84환산보증금
# 0  33000.0   0.0    0.0       32666.0
# 1  20000.0   0.0    0.0        9702.0
# 2  43000.0   0.0    0.0       30838.0
# 3  21500.0   0.0    0.0  19786.333333
# 4   5000.0  80.0   80.0        3658.0

# %%
df = pd.read_parquet("../data/processed/monthly_trade_summary.parquet")
print(df.size, len(df))
df.head()
# Out:
# 161280 11520
#        ym _lawd_cd _region_name  거래건수        평균거래금액  중앙값거래금액      평균84환산금액  \
# 0  201001    11110          종로구    23  42036.521739  27900.0  43703.304348
# 1  201001    11140           중구    35  47968.571429  42000.0       49536.0
# 2  201001    11170          용산구    92  75650.000000  64250.0   69799.76087
# 3  201001    11200          성동구   170  46390.294118  44000.0  50322.011765
# 4  201001    11215          광진구   118  52052.542373  48950.0  53963.135593
#
#    중앙값84환산금액      절사평균거래금액     평균전용면적     평균건물연령  평균거래금액_60㎡이하  평균거래금액_60~85㎡  \
# 0    42845.0  38454.736842  78.323913  11.043478  26022.222222   40663.333333
# 1    53440.0  47584.482759  80.492000   8.628571  33010.000000   50365.000000
# 2    70362.0  72097.972973  90.400913  17.021739  45256.000000   66045.000000
# 3    49927.5  45527.426471  77.684747  11.388235  36220.303030   49143.414634
# 4    55963.0  49220.833333  80.362119  13.872881  37048.837209   53583.870968
#
#     평균거래금액_85㎡초과
# ...

# %%
df = pd.read_parquet("../data/processed/apt_trade.parquet")
df.head()
# Out:
#         date  price  price_per_m2  price_per_py  price_std84    area  floor  \
# 0 2010-01-01  29850        580.29       1918.32        48744  51.440    5.0
# 1 2010-01-01  29000        483.64       1598.82        40626  59.962    4.0
# 2 2010-01-01  18000        392.16       1296.39        32941  45.900   12.0
# 3 2010-01-01  49700        584.91       1933.60        49133  84.970    6.0
# 4 2010-01-01  36300        607.43       2008.04        51024  59.760   13.0
#
#    construction_year   age dong       apt_name  area_repr   dong_repr  \
# 0               1985  25.0  천호동             우성         51  천호동(11740)
# 1               2002   8.0   상동  라일락마을(신성미소지움)         59   상동(41192)
# 2               1988  22.0  상계동      상계주공9(고층)         45  상계동(11350)
# 3               1993  17.0  평촌동         초원마을대원         84  평촌동(41173)
# 4               1999  11.0  가양동        가양강나루현대         59  가양동(11500)
#
#            apt_name_repr     aptSeq
# 0           우성-구천면로(천호동)  11740-173
# ...

# %%
df = pd.read_parquet("../data/processed/apt_rent.parquet")
df.head()
# Out:
#         date  deposit  deposit_per_m2  deposit_per_py  deposit_std84  \
# 0 2011-01-01     3100           52.19          172.52           4384
# 1 2011-01-01     5000           43.55          143.97           3658
# 2 2011-01-01     4700          100.09          330.86           8407
# 3 2011-01-01     1562           31.36          103.67           2634
# 4 2011-01-01     1249           31.51          104.16           2647
#
#    monthly_rent  monthly_rent_per_m2  monthly_rent_per_py    area  floor  ...  \
# 0             0                 0.00                 0.00   59.40   10.0  ...
# 1            80                 0.70                 2.30  114.81   18.0  ...
# 2            11                 0.23                 0.77   46.96    7.0  ...
# 3            11                 0.22                 0.73   49.81   15.0  ...
# 4             7                 0.18                 0.58   39.64    9.0  ...
#
#     age  dong     apt_name area_repr   dong_repr      apt_name_repr  \
# ...

# %%
df = pd.read_parquet("../data/raw/molit/apt_trade/11110_201501.parquet")
df.head()
# Out:
#   aptDong                aptNm      aptSeq bonbun bubun buildYear buyerGbn  \
# 0                        창신쌍용1    11110-37   0702  0000      1992
# 1          광화문스페이스본(101동~105동)  11110-2203   0009  0000      2008
# 2                           흥인    11110-40   0627  0021      1997
# 3                       종로센트레빌  11110-2224   0002  0001      2008
# 4          광화문스페이스본(101동~105동)  11110-2203   0009  0000      2008
#
#   cdealDay cdealType dealAmount  ... roadNmBonbun roadNmBubun roadNmCd  \
# 0                        34,000  ...        00019       00000  4100065
# 1                       110,000  ...        00004       00000  4100135
# 2                        17,800  ...        00131       00004  4100453
# 3                        39,000  ...        00047       00000  4100065
# 4                        73,000  ...        00004       00000  4100135
#
#   roadNmSeq roadNmSggCd roadNmbCd  sggCd slerGbn  umdCd umdNm
# 0        01       11110         0  11110          17400   창신동
# ...

# %%
sorted(df.columns)
# Out:
# ['aptDong',
#  'aptNm',
#  'aptSeq',
#  'bonbun',
#  'bubun',
#  'buildYear',
#  'buyerGbn',
#  'cdealDay',
#  'cdealType',
#  'dealAmount',
#  'dealDay',
#  'dealMonth',
#  'dealYear',
#  'dealingGbn',
#  'estateAgentSggNm',
#  'excluUseAr',
#  'floor',
#  'jibun',
#  'landCd',
#  'landLeaseholdGbn',
#  'rgstDate',
#  'roadNm',
#  'roadNmBonbun',
#  'roadNmBubun',
#  'roadNmCd',
#  'roadNmSeq',
#  'roadNmSggCd',
#  'roadNmbCd',
#  'sggCd',
#  'slerGbn',
#  'umdCd',
#  'umdNm']

# %%
df = pd.read_parquet("../data/raw/molit/building_ledger/building_ledger_all.parquet")
df.head()
# Out:
#   rnum                 platPlc sigunguCd bjdongCd platGbCd   bun    ji  \
# 0    1   서울특별시 종로구 창신동 601-8번지     11110    17400        0  0601  0008
# 1    1    서울특별시 종로구 평창동 46-1번지     11110    18300        0  0046  0001
# 2    1      서울특별시 종로구 익선동 55번지     11110    13300        0  0055  0000
# 3    1  서울특별시 종로구 숭인동 178-76번지     11110    17500        0  0178  0076
# 4    1      서울특별시 종로구 내수동 95번지     11110    11800        0  0095  0000
#
#   mgmBldrgstPk regstrGbCd regstrGbCdNm  ... engrRat engrEpi gnBldGrade  \
# 0   1002122300          2           집합  ...       0       0       None
# 1   1002112992          2           집합  ...       0       0       None
# 2   1002113267          2           집합  ...       0       0       None
# 3   1002125361          2           집합  ...       0       0       None
# 4   1002114180          2           집합  ...       0       0       None
#
#   gnBldCert itgBldGrade itgBldCert   crtnDay rserthqkDsgnApplyYn  \
# ...

# %%
sorted(df.columns)
# Out:
# ['aptSeq',
#  'archArea',
#  'atchBldArea',
#  'atchBldCnt',
#  'bcRat',
#  'bjdongCd',
#  'bldNm',
#  'block',
#  'bun',
#  'bylotCnt',
#  'crtnDay',
#  'dongNm',
#  'emgenUseElvtCnt',
#  'engrEpi',
#  'engrGrade',
#  'engrRat',
#  'etcPurps',
#  'etcRoof',
#  'etcStrct',
#  'fmlyCnt',
#  'gnBldCert',
#  'gnBldGrade',
#  'grndFlrCnt',
#  'heit',
#  'hhldCnt',
#  'hoCnt',
#  'indrAutoArea',
#  'indrAutoUtcnt',
#  'indrMechArea',
#  'indrMechUtcnt',
#  'itgBldCert',
#  'itgBldGrade',
#  'ji',
#  'lot',
#  'mainAtchGbCd',
#  'mainAtchGbCdNm',
#  'mainPurpsCd',
#  'mainPurpsCdNm',
#  'mgmBldrgstPk',
#  'naBjdongCd',
#  'naMainBun',
#  'naRoadCd',
#  'naSubBun',
#  'naUgrndCd',
#  'newPlatPlc',
#  'oudrAutoArea',
#  'oudrAutoUtcnt',
#  'oudrMechArea',
#  'oudrMechUtcnt',
#  'platArea',
#  'platGbCd',
#  'platPlc',
#  'pmsDay',
#  'pmsnoGbCd',
#  'pmsnoGbCdNm',
#  'pmsnoKikCd',
#  'pmsnoKikCdNm',
#  'pmsnoYear',
#  'regstrGbCd',
#  'regstrGbCdNm',
#  'regstrKindCd',
#  'regstrKindCdNm',
# ...

# %%
df = pd.read_parquet("../data/processed/monthly_rent_summary.parquet")
df.head()
# Out:
#        ym _lawd_cd _region_name  거래건수         평균보증금       평균월세
# 0  202001    11110          종로구   156  35899.243590  44.198718
# 1  202001    11140           중구   253  36417.885375  31.411067
# 2  202001    11170          용산구   380  47536.486842  35.436842
# 3  202001    11200          성동구   787  41628.898348  33.678526
# 4  202001    11215          광진구   310  40437.738710  23.993548

# %%
df._lawd_cd.unique()
# Out:
# array(['11110', '11140', '11170', '11200', '11215', '11230', '11260',
#        '11290', '11305', '11320', '11350', '11380', '11410', '11440',
#        '11470', '11500', '11530', '11545', '11560', '11590', '11620',
#        '11650', '11680', '11710', '11740', '41111', '41113', '41115',
#        '41117', '41131', '41133', '41135', '41171', '41173', '41192',
#        '41194', '41210', '41220', '41271', '41273', '41281', '41285',
#        '41287', '41410', '41430', '41461', '41463', '41465', '41591',
#        '41593', '41595'], dtype=object)

# %%
df._region_name.unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', '수원시 장안구',
#        '수원시 권선구', '수원시 팔달구', '수원시 영통구', '성남시 수정구', '성남시 중원구', '성남시 분당구',
#        '안양시 만안구', '안양시 동안구', '부천시 원미구', '부천시 소사구', '부천시 오정구', '광명시',
#        '평택시', '안산시 상록구', '안산시 단원구', '고양시 덕양구', '고양시 일산동구', '고양시 일산서구',
#        '군포시', '의왕시', '용인시 처인구', '용인시 기흥구', '용인시 수지구', '화성시 만세구',
#        '화성시 효행구', '화성시 병점구', '화성시 동탄구'], dtype=object)

# %%
df[df._region_name == "부천시 오정구"]
# Out:
#           ym _lawd_cd _region_name  거래건수         평균보증금       평균월세
# 36    202001    41196      부천시 오정구   243   7461.691358  16.814815
# 89    202002    41196      부천시 오정구   147  13368.809524  14.346939
# 142   202003    41196      부천시 오정구   117  10050.615385  15.666667
# 195   202004    41196      부천시 오정구   161  10542.888199  14.701863
# 248   202005    41196      부천시 오정구   167  12631.676647  13.341317
# ...      ...      ...          ...   ...           ...        ...
# 3561  202508    41196      부천시 오정구   108  14768.092593  28.009259
# 3613  202509    41196      부천시 오정구   125  15386.784000  25.328000
# 3665  202510    41196      부천시 오정구   102  14190.490196  31.960784
# 3717  202511    41196      부천시 오정구   113  14860.769912  33.840708
# 3769  202512    41196      부천시 오정구   160  11930.656250  34.618750
#
# [72 rows x 6 columns]

# %%
df = pd.read_parquet("../data/raw/molit/apt_trade/11110_202501.parquet")
df.head()
# Out:
#   aptDong      aptNm      aptSeq bonbun bubun buildYear buyerGbn cdealDay  \
# 0     102    인왕산아이파크  11110-2212   0060  0000      2008       개인
# 1     105         현대    11110-90   0082  0000      2000       개인
# 2     102      창신쌍용1    11110-37   0702  0000      1992       개인
# 3               엘리시아  11110-2261   0066  0001      2009       개인
# 4     202  인왕산2차아이파크  11110-2417   0088  0000      2015       개인
#
#   cdealType dealAmount  ... roadNmBonbun roadNmBubun roadNmCd roadNmSeq  \
# 0              115,000  ...        00009       00000  4100482        01
# 1              139,950  ...        00246       00020  3000008        06
# 2               69,500  ...        00019       00000  4100065        01
# 3              121,000  ...        00142       00000  3100023        01
# 4              111,500  ...        00034       00000  4100482        01
#
#   roadNmSggCd roadNmbCd  sggCd slerGbn  umdCd umdNm
# 0       11110         0  11110      개인  18700   무악동
# ...

# %%
df.T
# Out:
#                           0         1         2           3           4   \
# aptDong                  102       105       102                     202
# aptNm                인왕산아이파크        현대     창신쌍용1        엘리시아   인왕산2차아이파크
# aptSeq            11110-2212  11110-90  11110-37  11110-2261  11110-2417
# bonbun                  0060      0082      0702        0066        0088
# bubun                   0000      0000      0000        0001        0000
# buildYear               2008      2000      1992        2009        2015
# buyerGbn                  개인        개인        개인          개인          개인
# cdealDay
# cdealType
# dealAmount           115,000   139,950    69,500     121,000     111,500
# dealDay                   18        25        24          18          19
# dealMonth                  1         1         1           1           1
# dealYear                2025      2025      2025        2025        2025
# ...

# %%
df
# Out:
#    aptDong           aptNm      aptSeq bonbun bubun buildYear buyerGbn  \
# 0                    창신쌍용1    11110-37   0702  0000      1992
# 1                       삼성    11110-73   0596  0000      1998
# 2           광화문스페이스본(106동)  11110-2204   0009  0001      2008
# 3                       한빛    11110-27   0001  0030      1999
# 4                    창신쌍용1    11110-37   0702  0000      1992
# ..     ...             ...         ...    ...   ...       ...      ...
# 60                    킹스매너   11110-118   0110  0015      2004
# 61               종로청계힐스테이트  11110-2234   0766  0000      2009
# 62                 롯데캐슬천지인   11110-152   0076  0000      2004
# 63                   창신쌍용1    11110-37   0702  0000      1992
# 64                   창신쌍용2    11110-91   0703  0000      1993
#
#    cdealDay cdealType dealAmount  ... roadNmBonbun roadNmBubun roadNmCd  \
# 0                         31,000  ...        00019       00000  4100065
# ...
